# %% [markdown]
# [Matplotlib의 여러개 그래프를 하나의 figure에 그리기]
# - subplot()
# - subplots()

# %%
# [1-1] 모듈 로딩
import matplotlib.pyplot as plt
import numpy as np
import random as rd
import pandas as pd

# %%
DF=pd.read_csv('../../02.PANDAS/DATA/auto_mpg.csv')
plt.boxplot(DF['mpg'],label='mpg')
plt.legend()

# %%
DF=pd.read_csv('../../02.PANDAS/DATA/auto_mpg.csv')
b=plt.boxplot(DF['mpg'],label='mpg',vert=False)
plt.legend()
b
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x14c018f68e0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x14c018f6e20>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x14c018f6640>],
#  'medians': [<matplotlib.lines.Line2D at 0x14c019053a0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x14c01905640>],
#  'means': []}

# %%
DF=pd.read_csv('../../02.PANDAS/DATA/auto_mpg.csv')
plt.boxplot(DF['mpg'],label='mpg',notch=True)
plt.legend()

# %%
data_name=['mpg','cylinders','acceleration']
b=plt.boxplot(DF[data_name],label=data_name)
plt.legend()
plt.xticks([1,2,3],data_name)
b=b['fliers']
print(b[0].get_ydata())
DF.loc[DF['mpg']==46.6]
# Out:
# [46.6]
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 322  46.6          4          86.0         65    2110          17.9
#
#      model year  origin   car name
# 322          80       3  mazda glc
