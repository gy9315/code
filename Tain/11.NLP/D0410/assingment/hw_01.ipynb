# %%
import torch.nn as nn
class Skipgram(nn.Module):
    def __init__(self,vocab_size,embedding_size):
        super().__init__()
        self.embedding=nn.Embedding(vocab_size,embedding_size)
        self.linear=nn.Linear(embedding_size,vocab_size)
    def forward(self,data):
        embedding=self.embedding(data)
        return self.linear(embedding)

# %%
import pandas as pd
from Korpora import Korpora
from konlpy.tag import Okt
import re
import string
corpus=Korpora.load('nsmc')
corpus=pd.DataFrame(corpus.test)
punc=dict(zip(string.punctuation, ['']*len(string.punctuation)))
print(string.punctuation)
corpus.text=corpus.text.str.replace(r"[!\"""#$%&'()*+,-./:;<=>?@[\]^_`{|}~]",'',regex=True)

print(corpus.text[:3])
tokenizer=Okt()
rgex=re.compile(r'^[가-힣]+')
tokens=[(tokenizer.morphs(y),x) for x,y in enumerate(corpus.text) if re.search(rgex,y)]
print(tokens[:3])
# Out:
#     Korpora 는 다른 분들이 연구 목적으로 공유해주신 말뭉치들을
#     손쉽게 다운로드, 사용할 수 있는 기능만을 제공합니다.
#
#     말뭉치들을 공유해 주신 분들에게 감사드리며, 각 말뭉치 별 설명과 라이센스를 공유 드립니다.
#     해당 말뭉치에 대해 자세히 알고 싶으신 분은 아래의 description 을 참고,
#     해당 말뭉치를 연구/상용의 목적으로 이용하실 때에는 아래의 라이센스를 참고해 주시기 바랍니다.
#
#     # Description
#     Author : e9t@github
#     Repository : https://github.com/e9t/nsmc
#     References : www.lucypark.kr/docs/2015-pyconkr/#39
#
#     Naver sentiment movie corpus v1.0
#     This is a movie review dataset in the Korean language.
#     Reviews were scraped from Naver Movies.
#
#     The dataset construction is based on the method noted in
#     [Large movie review dataset][^1] from Maas et al., 2011.
#
#     [^1]: http://ai.stanford.edu/~amaas/data/sentiment/
#
#     # License
#     CC0 1.0 Universal (CC0 1.0) Public Domain Dedication
#     Details in https://creativecommons.org/publicdomain/zero/1.0/
#
# [Korpora] Corpus `nsmc` is already installed at C:\Users\gy931\Korpora\nsmc\ratings_train.txt
# [Korpora] Corpus `nsmc` is already installed at C:\Users\gy931\Korpora\nsmc\ratings_test.txt
# !"#$%&'()*+,-./:;<=>?@[\]^_`{|}~
# 0                                   굳 ㅋ
# 1                  GDNTOPCLASSINTHECLUB
# 2    뭐야 이 평점들은 나쁘진 않지만 10점 짜리는 더더욱 아니잖아
# Name: text, dtype: object
# [(['굳', 'ㅋ'], 0), (['뭐', '야', '이', '평점', '들', '은', '나쁘진', '않지만', '10', '점', '짜', '리', '는', '더', '더욱', '아니잖아'], 2), (['지루하지는', '않은데', '완전', '막장', '임', '돈', '주고', '보기', '에는'], 3)]

# %%
with open('../DATA/koreanStopword.txt') as f:
    stops=f.readlines()

stops=[x.replace('\n','') for x in stops]

# %%
for stop in  stops:
    corpus.text=corpus.text.apply(lambda x:x.translate(str.maketrans('','',stop)))

# %%
tokenizer=Okt()
rgex=re.compile(r'^[가-힣]+')
tokens=[(tokenizer.morphs(y),x) for x,y in enumerate(corpus.text) if re.search(rgex,y)]
print(tokens)
# Out:
# [(['굳', 'ㅋ'], 0), (['뭐평쁘', '10', '잖'], 2), (['루완돈'], 3), (['최', '화'], 5), (['레'], 6), (['애', '튀', '온', '창', '력', '봇젖'], 7), (['갈', '판화', '폼잡끝', 'cg', '립독', '화', '건', '3'], 8), (['별픔찾새쁨', 'But'], 9), (['괜찮', '랜', '포켓몬', '잼밌'], 10), (['독립', '화', '됨'], 11), (['청춘', '움', '성', '흔', '찰움', '포섬', '세', '채화', '퀴', '화'], 12), (['눈', '화흡', '력'], 13), (['출', '화', '화', '평화', '찍옥', '감독', '화', '력', 'OO', '화평', '빠져'], 14), (['최'], 16), (['발'], 17), (['별', '재', '먹', '챔프', '송', 'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ'], 19), (['훈돋평질섹코'], 21), (['꽤', '재밌', '화'], 22), (['민화', '억눌린', '욕', '출'], 23), (['황죄', '긴박', '루늘'], 24), (['괜', '올건', '긁던', '화', '봤', '새', '냥', '놈테', '놈놈', '올', '뻔'], 25), (['화', '찡', '벌', '4', '란', '흘렀'], 27), (['건뭐노', '8090', '린', '화'], 28), (['화뜻', '화'], 29), (['재밌'], 30), (['평', '1', '싫', '화배', '감독', '화판', '평티', '난'], 32), (['표현', '화'], 33), (['성', '액션', '판'], 34), (['재깝'], 36), (['북괴'], 37), (['셰피셰피화화'], 39), (['뭐'], 41), (['화'], 42), (['애갑'], 43), (['롭코헨락', 'OO'], 44), (['감'], 45), (['빛날'], 46), (['액션', '화', '굿굿'], 48), (['헷필', '50', '먹', '파워', '풀졌', 'ㅋㅋㅋㅋ'], 49), (['돈', 'ㅋ'], 50), (['레앙액션갔', 'ㅁㅊ'], 51), (['딴냥', '건', '세건', '발암', '질', '올'], 52), (['극', '갔', '감탄', '왔', '2001'], 53), (['재밌'], 54), (['난', '재밌던', '평케낮'], 55), (['역얘', '화', '배', '감독'], 56), (['칸웃맛'], 57), (['재밌'], 58), (['콩콩', 'ㅋㄲㅈㅁ'], 60), (['뭐', '봤', '돼'], 61), (['빠낚슈화'], 62), (['현', '징징', '징', '성', '현', '벗얘'], 63), (['엠', '채널', '봤', '엄청', '잼'], 64), (['웠웠'], 65), (['볼', '재밌'], 66), (['재', '봤'], 67), (['뻔', '슬프'], 68), (['업재'], 69), (['성혜', '롭친컴플렉잃륜긴'], 70), (['친놈', '출력', '빵빵', '성', '빵'], 71), (['염눈', '색깔', '뭐건뭐충', 'ㄹㄹ'], 72), (['볼', '재화'], 73), (['객독객독객독객독'], 74), (['완', 'ㅠㅜㅜㅜ'], 75), (['쇼', '넘', '돈테박', '재밌'], 76), (['재'], 77), (['볼'], 78), (['카벗쌩'], 79), (['솔건', 'C', '급', '화', '긴', 'ㅎㅎ'], 80), (['성', '몬귀뿜력퐁', '빠졌'], 81), (['찰', 'ㅋㅋㅋ'], 82), (['찔랑'], 84), (['재징', 'ㅎ'], 85), (['화', '끊', '빼', '넘'], 86), (['화', '긴', '필재충'], 87), (['최최', '4', '봇몽친', '탐험', '꺼', '갔'], 88), (['완잼'], 89), (['코굉즐화별뭔', '랑', '억', '낌'], 90), (['획', 'ㅜ'], 91), (['엔', '성', '넣', '극'], 92), (['감'], 93), (['뭘건'], 94), (['톱', '엔', '톱', '죠'], 95), (['완재', '밌평'], 96), (['완표', 'ㄷ'], 97), (['끔', '화색', '감죠', '강렬', '화', '츠던절볼'], 99), (['넘쳐난'], 100), (['펑', '퍼짐', '건빵', '카탈', '감독', '뒷', '돌', '화', '먹질'], 103), (['솔재밌랐봉낸린', 'ㅠㅠ', '봤', '커플', '댄', '쉽', '순', 'sm', '업', '화', '엔', '춤'], 104), (['평', '갔', '재', '찾', '볼', '특애코웃색투엄', '테', '잡던', '감', '깨져', '렸'], 105), (['글쌔슬프'], 107), (['땡얘', '낳'], 108), (['재밌', 'ㅠㅠ', '뭐랄굉뜻낌'], 109), (['화', '노잼'], 110), (['재밌욕셍', 'ㅠㅠ'], 111), (['땠', '협객', '패최', '먹', '평줌배린낌', '황민', '배', '화'], 112), (['재밌', '읽', '권충', '재화', '괴담', '플', '레', '재밌'], 113), (['괜찮'], 114), (['극화', '레'], 115), (['피', '표현', '화'], 117), (['뿌뜻애'], 118), (['렷박배감', 'ㅋㅋㅋㅋ'], 120), (['표투돼송쁘'], 121), (['평확', '재밌', '쾌'], 122), (['훌륭뛰난출훌륭', '뛰난', '졌'], 123), (['재화', '건재', '밋던'], 124), (['최잭', '님', '왔', '처볼땐', '꼈던', '재'], 125), (['레', '화재', 'ㅡㅡ'], 126), (['슴픈', '화질', '화', 'OST'], 127), (['화건탄레'], 128), (['재밋볼'], 129), (['갱닷'], 130), (['루화책넘'], 131), (['블', 'CG', '훌륭탈웃뻔움짧닝'], 132), (['트폐쇄', '갇힌', '변화'], 133), (['표현', '닿', '왕볼', '난건', '건랐', '화', '쥐표배', '화', '현', '력', '눈흘', '팠'], 134), (['뭐냥', '왔', '줬', '왔'], 135), (['재'], 136), (['재밌', 'ㅠ'], 137), (['잊', '화', '잔잔', '닿', '화낙피', '☆', '멋날', '☆', '햇', '춰', '행복', '빗', '껴졌'], 138), (['루볍', '볼', '코믹', '릴화잔릴', '화'], 139), (['민픔'], 140), (['화럽', '성루'], 141), (['화평', '읽', '화최재', 'ㅋ'], 142), (['재밌', '봤'], 143), (['쟁발봤'], 144), (['필', '력', '박', '냅란', '청률', '탁립'], 145), (['품성', '찝', '찝', '화'], 146), (['학루', '재화'], 147), (['뭐', '쟁손락꼽졌뻔뻔렸', '재', '10', '난', '화'], 150), (['클럽', '건혀섹', '클럽', '얘'], 151), (['엘쉘페퍼틴콜세쵝'], 152), (['웨껏화', 'ㅠㅠ'], 153), (['쾌웃'], 154), (['액션', '꽤', '괜찮', 'ㅎ'], 155), (['필', '화법', '법', '품던'], 156), (['노돈움'], 157), (['죠', '재밌', 'bb'], 158), (['필건', '발', '닦'], 159), (['굿'], 160), (['카츠', '3', '난', '올', '먹', '먹'], 161), (['완삶', '씩', '배워', '갈'], 162), (['루홈화'], 164), (['팬', '긴건', '봤', 'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ'], 165), (['케블', '광', '깔깔', '웃애', '흘눈돌릴프닿'], 166), (['발', '싸랑', '♥'], 167), (['화'], 168), (['별', '재 ...

# %%
idx=[y for x,y in tokens]
value=[x for x,y in tokens]
label=corpus.label.iloc[idx]
print(value)
# Out:
# [['굳', 'ㅋ'], ['뭐평쁘', '10', '잖'], ['루완돈'], ['최', '화'], ['레'], ['애', '튀', '온', '창', '력', '봇젖'], ['갈', '판화', '폼잡끝', 'cg', '립독', '화', '건', '3'], ['별픔찾새쁨', 'But'], ['괜찮', '랜', '포켓몬', '잼밌'], ['독립', '화', '됨'], ['청춘', '움', '성', '흔', '찰움', '포섬', '세', '채화', '퀴', '화'], ['눈', '화흡', '력'], ['출', '화', '화', '평화', '찍옥', '감독', '화', '력', 'OO', '화평', '빠져'], ['최'], ['발'], ['별', '재', '먹', '챔프', '송', 'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ'], ['훈돋평질섹코'], ['꽤', '재밌', '화'], ['민화', '억눌린', '욕', '출'], ['황죄', '긴박', '루늘'], ['괜', '올건', '긁던', '화', '봤', '새', '냥', '놈테', '놈놈', '올', '뻔'], ['화', '찡', '벌', '4', '란', '흘렀'], ['건뭐노', '8090', '린', '화'], ['화뜻', '화'], ['재밌'], ['평', '1', '싫', '화배', '감독', '화판', '평티', '난'], ['표현', '화'], ['성', '액션', '판'], ['재깝'], ['북괴'], ['셰피셰피화화'], ['뭐'], ['화'], ['애갑'], ['롭코헨락', 'OO'], ['감'], ['빛날'], ['액션', '화', '굿굿'], ['헷필', '50', '먹', '파워', '풀졌', 'ㅋㅋㅋㅋ'], ['돈', 'ㅋ'], ['레앙액션갔', 'ㅁㅊ'], ['딴냥', '건', '세건', '발암', '질', '올'], ['극', '갔', '감탄', '왔', '2001'], ['재밌'], ['난', '재밌던', '평케낮'], ['역얘', '화', '배', '감독'], ['칸웃맛'], ['재밌'], ['콩콩', 'ㅋㄲㅈㅁ'], ['뭐', '봤', '돼'], ['빠낚슈화'], ['현', '징징', '징', '성', '현', '벗얘'], ['엠', '채널', '봤', '엄청', '잼'], ['웠웠'], ['볼', '재밌'], ['재', '봤'], ['뻔', '슬프'], ['업재'], ['성혜', '롭친컴플렉잃륜긴'], ['친놈', '출력', '빵빵', '성', '빵'], ['염눈', '색깔', '뭐건뭐충', 'ㄹㄹ'], ['볼', '재화'], ['객독객독객독객독'], ['완', 'ㅠㅜㅜㅜ'], ['쇼', '넘', '돈테박', '재밌'], ['재'], ['볼'], ['카벗쌩'], ['솔건', 'C', '급', '화', '긴', 'ㅎㅎ'], ['성', '몬귀뿜력퐁', '빠졌'], ['찰', 'ㅋㅋㅋ'], ['찔랑'], ['재징', 'ㅎ'], ['화', '끊', '빼', '넘'], ['화', '긴', '필재충'], ['최최', '4', '봇몽친', '탐험', '꺼', '갔'], ['완잼'], ['코굉즐화별뭔', '랑', '억', '낌'], ['획', 'ㅜ'], ['엔', '성', '넣', '극'], ['감'], ['뭘건'], ['톱', '엔', '톱', '죠'], ['완재', '밌평'], ['완표', 'ㄷ'], ['끔', '화색', '감죠', '강렬', '화', '츠던절볼'], ['넘쳐난'], ['펑', '퍼짐', '건빵', '카탈', '감독', '뒷', '돌', '화', '먹질'], ['솔재밌랐봉낸린', 'ㅠㅠ', '봤', '커플', '댄', '쉽', '순', 'sm', '업', '화', '엔', '춤'], ['평', '갔', '재', '찾', '볼', '특애코웃색투엄', '테', '잡던', '감', '깨져', '렸'], ['글쌔슬프'], ['땡얘', '낳'], ['재밌', 'ㅠㅠ', '뭐랄굉뜻낌'], ['화', '노잼'], ['재밌욕셍', 'ㅠㅠ'], ['땠', '협객', '패최', '먹', '평줌배린낌', '황민', '배', '화'], ['재밌', '읽', '권충', '재화', '괴담', '플', '레', '재밌'], ['괜찮'], ['극화', '레'], ['피', '표현', '화'], ['뿌뜻애'], ['렷박배감', 'ㅋㅋㅋㅋ'], ['표투돼송쁘'], ['평확', '재밌', '쾌'], ['훌륭뛰난출훌륭', '뛰난', '졌'], ['재화', '건재', '밋던'], ['최잭', '님', '왔', '처볼땐', '꼈던', '재'], ['레', '화재', 'ㅡㅡ'], ['슴픈', '화질', '화', 'OST'], ['화건탄레'], ['재밋볼'], ['갱닷'], ['루화책넘'], ['블', 'CG', '훌륭탈웃뻔움짧닝'], ['트폐쇄', '갇힌', '변화'], ['표현', '닿', '왕볼', '난건', '건랐', '화', '쥐표배', '화', '현', '력', '눈흘', '팠'], ['뭐냥', '왔', '줬', '왔'], ['재'], ['재밌', 'ㅠ'], ['잊', '화', '잔잔', '닿', '화낙피', '☆', '멋날', '☆', '햇', '춰', '행복', '빗', '껴졌'], ['루볍', '볼', '코믹', '릴화잔릴', '화'], ['민픔'], ['화럽', '성루'], ['화평', '읽', '화최재', 'ㅋ'], ['재밌', '봤'], ['쟁발봤'], ['필', '력', '박', '냅란', '청률', '탁립'], ['품성', '찝', '찝', '화'], ['학루', '재화'], ['뭐', '쟁손락꼽졌뻔뻔렸', '재', '10', '난', '화'], ['클럽', '건혀섹', '클럽', '얘'], ['엘쉘페퍼틴콜세쵝'], ['웨껏화', 'ㅠㅠ'], ['쾌웃'], ['액션', '꽤', '괜찮', 'ㅎ'], ['필', '화법', '법', '품던'], ['노돈움'], ['죠', '재밌', 'bb'], ['필건', '발', '닦'], ['굿'], ['카츠', '3', '난', '올', '먹', '먹'], ['완삶', '씩', '배워', '갈'], ['루홈화'], ['팬', '긴건', '봤', 'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ'], ['케블', '광', '깔깔', '웃애', '흘눈돌릴프닿'], ['발', '싸랑', '♥'], ['화'], ['별', '재', '7'], ['노섹', '엔화', '활'], ['멀', '포', 'ㅁ'], ['역', '화', '볼', '덕성'], ['풍', '감맨즐', '화', '뭇', '봤', 'ㅎㅎㅎ'], ['쉬', '먼건', '뭐병건'], ['님뇌껴숭감'], ['발량', '급', '평화', '업슴', '극', '최평', '1', '깝'], ['급', '웠역액션뎀', '성', '님', '맡'], ['란란'], ['먼낀색콜릿맛화랄'], ['화찍', '화', '찍', 'ㅉㅉ'], ['뭐', '재밌', 'ㅋㅋㅋ', '최'], ['릴감화잊트', '던', '억', '꼭', '파세', 'dodadannavercom'], ['맨', '색법', '뭘건'], ['헤', '클레', '묘'], ['뭐워'], ['죠', '배', '억'], ['카'], ['화역웠척', '앵글', '잡', '괜찮', '화', '세', '덩'], ['최'], ['랑', '화'], ['승화', '좌절', '화'], ['재랐', 'ㅋㅋ'], ['카', '랑', '재밌', '봤', '샤'], ['품', '됨', '엑', '끝냄', '화최'], ['날애'], ['성', '성', '힌', '탈출', '덫'], ['건박걍잼슴'], ['친앙세뚜렷강'], ['억', '잼'], ['평', '쓴', '삭'], ['순', '럽화끌루쉬움감레', '궁', '졌'], ['섭', '끔', '찍던'], ['옴발코행', '110', '쯤', '10', '화'], ['낸질', '온', '독립', '화', '글'], ['젊', '열', '격움묻', '화'], ['화'], ['엄화굿'], ['쾌'], ['청뜸'], ['산잔', '화북', '암'], ['화뭘건'], ['글쎄'], ['역팀', '튼'], ['노력', '욕', '새', '뀌'], ['애'], ['별', '던', 'ㅠㅠ', '냥랬'], ['화난', '극'], ['볍', '성화'], [ ...

# %%
from collections import Counter
def bulid_vocab(corpus,n_vocab,special):
    count=Counter(y for x in corpus for y in x)
    vocab=special
    count=count.most_common(n_vocab)
    for x, y in count:
        vocab.append(x)
    return {x:y for x,y in enumerate(vocab)},{y:x for x,y in enumerate(vocab)}

# %%
id2s,s2id=bulid_vocab(value,5000,['<unk>'])
print(id2s)
# Out:
# {0: '<unk>', 1: '화', 2: '재밌', 3: '봤', 4: '랑', 5: '재', 6: '최', 7: '감독', 8: '성', 9: '감', 10: 'ㅋㅋ', 11: '별', 12: '난', 13: '억', 14: '냥', 15: '평', 16: '극', 17: '액션', 18: '1', 19: 'ㅠㅠ', 20: '력', 21: '세', 22: '10', 23: 'ㅋ', 24: '님', 25: '엔', 26: 'ㅋㅋㅋ', 27: 'ㅡㅡ', 28: '넘', 29: '출', 30: '배', 31: '2', 32: '건', 33: '볼', 34: '현', 35: '뭔', 36: '괜찮', 37: '긴', 38: '올', 39: '처', 40: '뭐', 41: '3', 42: '먹', 43: '짱', 44: 'ㅎㅎ', 45: '역', 46: '맞', 47: '순', 48: '애', 49: '캐릭', 50: '왔', 51: '코', 52: '레', 53: '던', 54: '높', 55: '잼', 56: '웃', 57: '루', 58: '온', 59: '깝', 60: '끝', 61: '품', 62: '표현', 63: '화재', 64: '급', 65: '갈', 66: '포화', 67: '찾', 68: '눈', 69: '박', 70: 'ㅜㅜ', 71: '새', 72: 'ㅠ', 73: '화평', 74: '잔잔', 75: '깊', 76: '죠', 77: '린', 78: '족', 79: '재화', 80: '쳐', 81: 'ㅎ', 82: '쉽', 83: '멋', 84: '맨', 85: '귀', 86: '발', 87: '포', 88: 'ㅋㅋㅋㅋ', 89: '엄청', 90: '낌', 91: '노잼', 92: '떨', 93: '증', 94: '열', 95: '죽', 96: '워', 97: '행복', 98: '딴', 99: '절', 100: '싸', 101: '강', 102: '믿', 103: '학', 104: '킬링', 105: '봤던', 106: '싫', 107: '필', 108: '친', 109: '슬프', 110: '움', 111: '완벽', 112: '꼭', 113: 'OO', 114: '굿', 115: '껴', 116: '돋', 117: '옛날', 118: '판', 119: '5', 120: '노', 121: '뻔', 122: '♥', 123: '4', 124: '솔', 125: '피', 126: '코믹', 127: '충격', 128: '났', 129: '됨', 130: '첨', 131: '굳', 132: '왕', 133: '먼', 134: '백', 135: '평낮', 136: '돌', 137: '왠', 138: '릴', 139: '행', 140: '돈', 141: '끔', 142: '티', 143: '민', 144: '감성', 145: '큰', 146: '걍', 147: '갔', 148: '질', 149: '란', 150: '7', 151: '석', 152: '평화', 153: 'ㅉㅉ', 154: '존재', 155: '험', 156: '8', 157: '권', 158: '줘', 159: '카', 160: '낸', 161: '봉', 162: '클', 163: '빠져', 164: '찍', 165: '틱', 166: '멜', 167: '져', 168: '0', 169: '됐', 170: '잊', 171: '독특', 172: '뜻', 173: '재밋', 174: '글', 175: '뛰', 176: '완재', 177: '욕', 178: '20', 179: '접', 180: '늘', 181: '색', 182: '건화', 183: '성룡', 184: '완', 185: '럽', 186: '질질', 187: '슬픈', 188: '닌', 189: '암', 190: '날', 191: '튼', 192: '끄', 193: '창', 194: '읽', 195: '애화', 196: '흔', 197: '노출', 198: '프랑', 199: '돼', 200: '꺼', 201: '탄탄', 202: '병맛', 203: '성화', 204: '6', 205: '화성', 206: '줬', 207: '잡', 208: '쯤', 209: '산', 210: '봄', 211: 'ㅎㅎㅎ', 212: '충', 213: '쓸', 214: '듣', 215: '귀엽', 216: '쾌', 217: '화최', 218: '존', 219: '범죄', 220: '낄', 221: '풍', 222: '9', 223: '황', 224: '놔', 225: '파', 226: '출력', 227: '웃긴', 228: '완성', 229: '커', 230: '평범', 231: '잖', 232: '환', 233: '훌륭', 234: '섭', 235: '노력', 236: '멘', 237: '능력', 238: '테', 239: '삶', 240: '100', 241: '댓글', 242: 'ㅠㅠㅠ', 243: '갑', 244: '십', 245: 'ㄷㄷ', 246: '쓴', 247: 'ㅋㅋㅋㅋㅋ', 248: '복', 249: '씩', 250: '태', 251: '잃', 252: '플', 253: '홍콩', 254: '쌍', 255: '잔', 256: '베', 257: '탄', 258: '투', 259: '독립', 260: 'OOO', 261: '객', 262: '재재', 263: '트', 264: '줌', 265: '뜨', 266: '청', 267: '놈', 268: '낮', 269: '졌', 270: 'CG', 271: 'TV', 272: '12', 273: '엄청난', 274: '채널', 275: '책', 276: '끌', 277: '담', 278: 'ㅜ', 279: '독', 280: '뜬', 281: '재밌던', 282: '품성', 283: '넣', 284: '얘', 285: '흑', 286: '뭘', 287: '청춘', 288: '♡', 289: '극화', 290: '맘', 291: '화감', 292: 'B', 293: '혀', 294: '큐', 295: '감감', 296: '립', 297: '렸', 298: '팬', 299: '표', 300: '엿', 301: '패', 302: '프', 303: '찝', 304: '슴', 305: '짱짱', 306: '빨', 307: '온화', 308: '빼', 309: '즌', 310: '낭', 311: '즘', 312: '짐', 313: '벌', 314: '감탄', 315: '낀', 316: '광', 317: '쉬', 318: '젊', 319: '쳤', 320: '업', 321: '즐', 322: '푸', 323: '건뭐', 324: '빌', 325: '빠', 326: '확', 327: '화포', 328: '화볼', 329: '봅', 330: '화질', 331: '궁', 332: '현재', 333: '힐링', 334: '레화', 335: '눈빛', 336: '루루', 337: '커플', 338: '법', 339: '겼', 340: '꼈', 341: '쁘', 342: '산화', 343: '꽤', 344: '랑랑', 345: '능', 346: '새벽', 347: '프레', 348: '꿈', 349: '30', 350: '평평', 351: '변', 352: '발화', 353: '깔', 354: '덕', 355: '재감', 356: '잊혀', 357: '필화', 358: '빙', 359: '슬픔', 360: '됬', 361: '90', 362: '효', 363: '폭력', 364: '풀', 365: '똑', 366: 'cg', 367: 'SF', 368: '됩', 369: '짧', 370: 'ost', 371: '닿', 372: '화난', 373: '밀', 374: '씀', 375: '재던', 376: '홍', 377: '맛', 378: '글쎄', 379: '코난', 380: '웠', 381: '웬', 382: '풋풋', 383: '포트', 384: '화란', 385: '활', 386: '멀', 387: '옴', 388: '80', 389: '엘', 390: '씁', 391: 'ㅡ', 392: '끊', 393: '끝날', 394: '감재', 395: '돈화', 396: '센',  ...

# %%
def get_word_pairs(tokens,windowsize):
    pair=[]
    for sentence in tokens:
        sent_len=len(sentence)
        for idx,center_word in enumerate(sentence):
            window_start=max(0,idx-windowsize)
            window_end=min(sent_len,idx+windowsize+1)
            center_word=sentence[idx]
            context_word=sentence[window_start:idx]+sentence[idx+1:window_end]
            for context in context_word:
                pair.append([center_word,context])
    return pair
word_pair=get_word_pairs(value,windowsize=2)

# %%
def get_index_pair(word_pair,s2id):
    pairs=[]
    unk_idx=s2id['<unk>']
    for x,y in word_pair:
        center_idx=s2id.get(x,unk_idx)
        context_idx=s2id.get(y,unk_idx)
        pairs.append([center_idx,context_idx])
    return pairs
index_pairs=get_index_pair(word_pair,s2id)
print(index_pairs[:5])
# Out:
# [[131, 23], [23, 131], [3754, 22], [3754, 231], [22, 3754]]

# %%
import torch
from torch.utils.data import TensorDataset,DataLoader
index_pairs=torch.tensor(index_pairs)
center_index=index_pairs[:,0]
context_index=index_pairs[:,1]
dataset=TensorDataset(center_index,context_index)
dataloader=DataLoader(dataset,batch_size=32,shuffle=True)

# %%
from torch.optim.lr_scheduler import ReduceLROnPlateau
import torch.optim as optim
from torchmetrics import Accuracy
import torch.nn.functional as F

device='cuda' if torch.cuda.is_available() else 'cpu'
word2vec=Skipgram(len(s2id),128).to(device)
optimizer=optim.SGD(word2vec.parameters(),lr=0.01)
LR=ReduceLROnPlateau(optimizer,mode='min',patience=4)
accuarcy=Accuracy(task='multiclass',num_classes=len(s2id))
for epoch in range(10):
    loss_score=0
    num=0
    pred_list=[]
    target_list=[]
    for label,target in dataloader:
        optimizer.zero_grad()
        output=word2vec(label)
        loss=F.cross_entropy(output,target)
        loss_score+=loss.item()
        num+=label.size(0)
        loss.backward()
        pred_list.extend(torch.argmax(output,dim=1).tolist())
        target_list.extend(target.tolist())
        optimizer.step()
    accur=accuarcy(torch.tensor(pred_list,dtype=torch.int64),torch.tensor(target_list,dtype=torch.int64))
    LR.step(loss_score)
    print(f'epoch: {epoch}')
    print(f'정확도: {accur},loss: {loss_score/num:3f}')
# Out:
# epoch: 0
# 정확도: 0.13366760313510895,loss: 0.228346
# epoch: 1
# 정확도: 0.15125392377376556,loss: 0.209241
# epoch: 2
# 정확도: 0.151728555560112,loss: 0.203346
# epoch: 3
# 정확도: 0.15187205374240875,loss: 0.199440
# epoch: 4
# 정확도: 0.15225285291671753,loss: 0.196491
# epoch: 5
# 정확도: 0.15228873491287231,loss: 0.194159
# epoch: 6
# 정확도: 0.15221698582172394,loss: 0.192258
# epoch: 7
# 정확도: 0.15242119133472443,loss: 0.190674
# epoch: 8
# 정확도: 0.15228873491287231,loss: 0.189325
# epoch: 9
# 정확도: 0.1526115983724594,loss: 0.188160

# %%
from gensim.models import Word2Vec
word2vec=Word2Vec(sentences=value,vector_size=128,window=5,min_count=1,sg=1,epochs=3 ,max_final_vocab=1000)

# %%
word='연기'
print(word2vec.wv['감독'])
print(word2vec.wv.most_similar('감독',topn=5))
# Out:
# [ 0.05565764 -0.18748531  0.09263194  0.11231352  0.09089813 -0.06953272
#   0.16616842  0.01461796 -0.06435889  0.11303689  0.13444246 -0.05505151
#   0.01070715 -0.08946592  0.17383195  0.15742725 -0.16213436  0.03463842
#  -0.10029705  0.14314124  0.11848484  0.12814276 -0.08584572 -0.26323164
#  -0.22286089  0.1407294  -0.15865055  0.12254064  0.07108829 -0.08987392
#  -0.0082429   0.00119662  0.06086351  0.02917311 -0.02454914  0.11212895
#   0.17575939 -0.1084668   0.0065128   0.04321606 -0.07458648  0.1394718
#  -0.04439687 -0.07261654  0.24312295  0.04826201 -0.13813412 -0.00575774
#  -0.03462795  0.10875429  0.09591789  0.08296204  0.031918    0.07794387
#  -0.02287239 -0.04574638  0.19653796  0.01388425 -0.10818078  0.01681638
#  -0.12259272 -0.03292376  0.12016308 -0.08301152  0.13983321 -0.03644155
#   0.05072473  0.03002098 -0.01360066 -0.13540535 -0.01548785 -0.10515512
#  -0.31965807 -0.11424354  0.02371702 -0.176538   -0.15817444 -0.02877799
#  -0.09940577  0.1702786  -0.03579236 -0.10734967  0.16430055  0.25167882
#   0.2591301   0.12778758  0.14039706 -0.1493889   0.08724867  0.14771967
#  -0.0802983  -0.13055952  0.13952625 -0.06383956  0.1109648   0.1029805
#  -0.17323574 -0.19072023 -0.15672037 -0.04636945 -0.14080422  0.02995869
#  -0.13848516  0.06513315  0.11283068  0.01768889  0.0109014   0.09768842
#   0.17593369 -0.13572253  0.02802355 -0.20351666  0.04516952  0.14161192
#  -0.14031895 -0.0053578  -0.00304082  0.08482957  0.01880272 -0.00369433
#  -0.14220366 -0.11513846 -0.08925969  0.01293318 -0.02362447 -0.07309459
#  -0.05802855  0.04851605]
# [('님', 0.9967178702354431), ('출', 0.9960126280784607), ('족', 0.9949241280555725), ('현', 0.9946449398994446), ('꿈', 0.9946267604827881)]
