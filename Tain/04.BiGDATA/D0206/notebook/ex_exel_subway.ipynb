# %%
import pandas as pd
from tabulate import tabulate

DF=pd.read_csv('../data/subwaytime.csv',header=[0,1])

# %%
DF.columns
# Out:
# MultiIndex([(                '사용월', 'Unnamed: 0_level_1'),
#             (                '호선명', 'Unnamed: 1_level_1'),
#             (                '역ID', 'Unnamed: 2_level_1'),
#             (               '지하철역', 'Unnamed: 3_level_1'),
#             (  '04:00:00~04:59:59',                 '승차'),
#             ( 'Unnamed: 5_level_0',                 '하차'),
#             (  '05:00:00~05:59:59',                 '승차'),
#             ( 'Unnamed: 7_level_0',                 '하차'),
#             (  '06:00:00~06:59:59',                 '승차'),
#             ( 'Unnamed: 9_level_0',                 '하차'),
#             (  '07:00:00~07:59:59',                 '승차'),
#             ('Unnamed: 11_level_0',                 '하차'),
#             (  '08:00:00~08:59:59',                 '승차'),
#             ('Unnamed: 13_level_0',                 '하차'),
#             (  '09:00:00~09:59:59',                 '승차'),
#             ('Unnamed: 15_level_0',                 '하차'),
# ...

# %%
DF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 621 entries, 0 to 620
# Data columns (total 52 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   (사용월, Unnamed: 0_level_1)   621 non-null    object
#  1   (호선명, Unnamed: 1_level_1)   621 non-null    object
#  2   (역ID, Unnamed: 2_level_1)   621 non-null    int64
#  3   (지하철역, Unnamed: 3_level_1)  621 non-null    object
#  4   (04:00:00~04:59:59, 승차)     621 non-null    int64
#  5   (Unnamed: 5_level_0, 하차)    621 non-null    int64
#  6   (05:00:00~05:59:59, 승차)     621 non-null    int64
#  7   (Unnamed: 7_level_0, 하차)    621 non-null    int64
#  8   (06:00:00~06:59:59, 승차)     621 non-null    int64
#  9   (Unnamed: 9_level_0, 하차)    621 non-null    int64
#  10  (07:00:00~07:59:59, 승차)     621 non-null    int64
#  11  (Unnamed: 11_level_0, 하차)   621 non-null    int64
#  12  (08:00:00~08:59:59, 승차)     621 non-null    int64
# ...

# %%
DF.head()
# Out:
#                  사용월                호선명                역ID               지하철역  \
#   Unnamed: 0_level_1 Unnamed: 1_level_1 Unnamed: 2_level_1 Unnamed: 3_level_1
# 0             Dec.24                1호선                150                서울역
# 1             Dec.24                1호선                151                 시청
# 2             Dec.24                1호선                152                 종각
# 3             Dec.24                1호선                153               종로3가
# 4             Dec.24                1호선                154               종로5가
#
#   04:00:00~04:59:59 Unnamed: 5_level_0 05:00:00~05:59:59 Unnamed: 7_level_0  \
#                  승차                 하차                승차                 하차
# 0               622                 26              7885               7893
# 1               113                  3              1896               4707
# 2               160                 10              4229               5618
# ...

# %%
DF.iloc[:,4:9:2].sum(axis=1).max()
# Out:
# 103486

# %%
DF.id
